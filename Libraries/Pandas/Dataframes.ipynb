# %%
import numpy as np
import pandas as pd

# %%
data={
    "Name":['John','David','Peter'],
    'Age':[17,12,23],
    "City":['New Work','Paris','London']
}

df=pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City
# 0   John   17  New Work
# 1  David   12     Paris
# 2  Peter   23    London

# %% [markdown]
# Selecting

# %%
data=[
    ["John",28,"New York","18k"],
    ['Peter',18,'London',"16k"],
    ['Anna',19,'Berlin',"45k"],
    ["Jake",22,"Paris","30k"]
]

df2 = pd.DataFrame(data, columns=['Name','Age','City','Salary'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\machine learning\.venv\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File c:\machine learning\.venv\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
# ...

# %%
df2
# Out:
#     Name  Age      City Salary
# 0   John   28  New York   None
# 1  Peter   18    London   None
# 2   Anna   19    Berlin   None
# 3    18k  16k       45k    25k
